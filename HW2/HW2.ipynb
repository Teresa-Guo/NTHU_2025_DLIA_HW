# %% [markdown]
# <div align="center">
#
# ###### Lab 2
#
# # National Tsing Hua University
#
# #### Spring 2025
#
# #### 11320IEEM 513600
#
# #### Deep Learning and Industrial Applications
#
# ## Lab 2: Predicting Heart Disease with Deep Learning
#
# </div>

# %% [markdown]
# ### Introduction
#
# In the realm of healthcare, early detection and accurate prediction of diseases play a crucial role in patient care and management. Heart disease remains one of the leading causes of mortality worldwide, making the development of effective diagnostic tools essential. This lab leverages deep learning to predict the presence of heart disease in patients using a subset of 14 key attributes from the Cleveland Heart Disease Database. The objective is to explore and apply deep learning techniques to distinguish between the presence and absence of heart disease based on clinical parameters.
#
# Throughout this lab, you'll engage with the following key activities:
# - Use [Pandas](https://pandas.pydata.org) to process the CSV files.
# - Use [PyTorch](https://pytorch.org) to build an Artificial Neural Network (ANN) to fit the dataset.
# - Evaluate the performance of the trained model to understand its accuracy.
#
# ### Attribute Information
#
# 1. age: Age of the patient in years
# 2. sex: (Male/Female)
# 3. cp: Chest pain type (4 types: low, medium, high, and severe)
# 4. trestbps: Resting blood pressure
# 5. chol: Serum cholesterol in mg/dl
# 6. fbs: Fasting blood sugar > 120 mg/dl
# 7. restecg: Resting electrocardiographic results (values 0,1,2)
# 8. thalach: Maximum heart rate achieved
# 9. exang: Exercise induced angina
# 10. oldpeak: Oldpeak = ST depression induced by exercise relative to rest
# 11. slope: The slope of the peak exercise ST segment
# 12. ca: Number of major vessels (0-3) colored by fluoroscopy
# 13. thal: 3 = normal; 6 = fixed defect; 7 = reversible defect
# 14. target: target have disease or not (1=yes, 0=no)
#
# ### References
# - [UCI Heart Disease Data](https://www.kaggle.com/datasets/redwankarimsony/heart-disease-data) for the dataset we use in this lab.

# %% [markdown]
# ## A. Checking and Preprocessing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/深度學習 Colab/heart_dataset_train_all.csv')
df
# Out:
#      age     sex      cp  trestbps   chol  fbs  restecg  thalach  exang  \
# 0     41    Male  medium     105.0  198.0    0      1.0    168.0      0
# 1     65  Female     low     120.0  177.0    0      1.0    140.0      0
# 2     44  Female  medium     130.0  219.0    0      0.0    188.0      0
# 3     54  Female    high     125.0  273.0    0      0.0    152.0      0
# 4     51  Female  severe     125.0  213.0    0      0.0    125.0      1
# ..   ...     ...     ...       ...    ...  ...      ...      ...    ...
# 268   40  Female     low     110.0  167.0    0      0.0    114.0      1
# 269   60  Female     low     117.0  230.0    1      1.0    160.0      1
# 270   64  Female    high     140.0  335.0    0      1.0    158.0      0
# 271   43  Female     low     120.0  177.0    0      0.0    120.0      1
# 272   57  Female     low     150.0  276.0    0      0.0    112.0      1
#
#      oldpeak  slope  ca  thal  target
# 0        0.0    2.0   1   2.0     1.0
# 1        0.4    2.0   0   3.0     1.0
# 2        0.0    2.0   0   2.0     1.0
# 3        0.5    0.0   1   2.0     1.0
# 4        1.4    2.0   1   2.0     1.0
# ..       ...    ...  ..   ...     ...
# 268      2.0    1.0   0   3.0     0.0
# 269      1.4    2.0   2   3.0     0.0
# 270      0.0    2.0   0   2.0     0.0
# 271      2.5    1.0   0   3.0     0.0
# 272      0.6    1.0   1   1.0     0.0
#
# [273 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       273 non-null    int64
#  1   sex       272 non-null    object
#  2   cp        272 non-null    object
#  3   trestbps  272 non-null    float64
#  4   chol      271 non-null    float64
#  5   fbs       273 non-null    int64
#  6   restecg   272 non-null    float64
#  7   thalach   272 non-null    float64
#  8   exang     273 non-null    int64
#  9   oldpeak   273 non-null    float64
#  10  slope     271 non-null    float64
#  11  ca        273 non-null    int64
#  12  thal      272 non-null    float64
#  13  target    272 non-null    float64
# dtypes: float64(8), int64(4), object(2)
# memory usage: 30.0+ KB

# %%
# checking for null values
df.isnull().sum()
# Out:
# age         0
# sex         1
# cp          1
# trestbps    1
# chol        2
# fbs         0
# restecg     1
# thalach     1
# exang       0
# oldpeak     0
# slope       2
# ca          0
# thal        1
# target      1
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (270, 14)

# %%
# Mapping 'sex' descriptions to numbers
sex_description = {
    'Male': 0,
    'Female': 1,
}
df.loc[:, 'sex'] = df['sex'].map(sex_description) # .loc 選取所有的列與 sex 這一欄的所有值；.map(sex_description) 將 sex 欄位的值依照 sex_description 字典轉換

# Mapping 'cp' (chest pain) descriptions to numbers
pain_description = {
    'low': 0,
    'medium': 1,
    'high': 2,
    'severe': 3
}
df.loc[:, 'cp'] = df['cp'].map(pain_description)

df
# Out:
#      age sex cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     41   0  1     105.0  198.0    0      1.0    168.0      0      0.0
# 1     65   1  0     120.0  177.0    0      1.0    140.0      0      0.4
# 2     44   1  1     130.0  219.0    0      0.0    188.0      0      0.0
# 3     54   1  2     125.0  273.0    0      0.0    152.0      0      0.5
# 4     51   1  3     125.0  213.0    0      0.0    125.0      1      1.4
# ..   ...  .. ..       ...    ...  ...      ...      ...    ...      ...
# 268   40   1  0     110.0  167.0    0      0.0    114.0      1      2.0
# 269   60   1  0     117.0  230.0    1      1.0    160.0      1      1.4
# 270   64   1  2     140.0  335.0    0      1.0    158.0      0      0.0
# 271   43   1  0     120.0  177.0    0      0.0    120.0      1      2.5
# 272   57   1  0     150.0  276.0    0      0.0    112.0      1      0.6
#
#      slope  ca  thal  target
# 0      2.0   1   2.0     1.0
# 1      2.0   0   3.0     1.0
# 2      2.0   0   2.0     1.0
# 3      0.0   1   2.0     1.0
# 4      2.0   1   2.0     1.0
# ..     ...  ..   ...     ...
# 268    1.0   0   3.0     0.0
# 269    2.0   2   3.0     0.0
# 270    2.0   0   2.0     0.0
# 271    1.0   0   3.0     0.0
# 272    1.0   1   1.0     0.0
#
# [270 rows x 14 columns]

# %%
df.describe()
# Out:
#               age    trestbps        chol         fbs     restecg     thalach  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.385185  131.525926  245.607407    0.151852    0.522222  149.807407
# std      9.149713   17.904675   51.529411    0.359544    0.529314   23.217253
# min     29.000000   94.000000  126.000000    0.000000    0.000000   71.000000
# 25%     47.250000  120.000000  210.250000    0.000000    0.000000  134.500000
# 50%     56.000000  130.000000  240.500000    0.000000    1.000000  152.500000
# 75%     61.000000  140.000000  274.000000    0.000000    1.000000  167.750000
# max     77.000000  200.000000  564.000000    1.000000    2.000000  202.000000
#
#             exang     oldpeak       slope          ca        thal      target
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     0.333333    1.024074    1.400000    0.744444    2.300000    0.544444
# std      0.472280    1.188379    0.618188    1.037166    0.623874    0.498946
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    0.000000    2.000000    0.000000
# 50%      0.000000    0.600000    1.000000    0.000000    2.000000    1.000000
# 75%      1.000000    1.600000    2.000000    1.000000    3.000000    1.000000
# max      1.000000    6.200000    2.000000    4.000000    3.000000    1.000000

# %%
df.corr() # 計算欄位之間的相關係數
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.062222 -0.103697  0.261782  0.210520  0.109847
# sex      -0.062222  1.000000 -0.040197 -0.055463 -0.166885  0.042384
# cp       -0.103697 -0.040197  1.000000  0.035563 -0.063592  0.065869
# trestbps  0.261782 -0.055463  0.035563  1.000000  0.128444  0.170606
# chol      0.210520 -0.166885 -0.063592  0.128444  1.000000  0.003430
# fbs       0.109847  0.042384  0.065869  0.170606  0.003430  1.000000
# restecg  -0.124588 -0.069599  0.008389 -0.145195 -0.162687 -0.086165
# thalach  -0.412624 -0.058626  0.300307 -0.056631 -0.023753 -0.014297
# exang     0.111263  0.124054 -0.428233  0.067116  0.063902  0.029190
# oldpeak   0.200243  0.089726 -0.183616  0.184896  0.084355  0.007943
# slope    -0.165360 -0.038771  0.135174 -0.126553 -0.031929 -0.056866
# ca        0.254462  0.140795 -0.180598  0.093545  0.068647  0.164266
# thal      0.077368  0.198493 -0.139765  0.068690  0.121280 -0.004972
# target   -0.244798 -0.283776  0.425574 -0.173239 -0.096773 -0.068845
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.124588 -0.412624  0.111263  0.200243 -0.165360  0.254462
# sex      -0.069599 -0.058626  0.124054  0.089726 -0.038771  0.140795
# cp        0.008389  0.300307 -0.428233 -0.183616  0.135174 -0.180598
# trestbps -0.145195 -0.056631  0.067116  0.184896 -0.126553  0.093545
# chol     -0.162687 -0.023753  0.063902  0.084355 -0.031929  0.068647
# fbs      -0.086165 -0.014297  0.029190  0.007943 -0.056866  0.164266
# restecg   1.000000  0.025457 -0.089225 -0.047837  0.074982 -0.053946
# thalach   0.025457  1.000000 -0.404349 -0.340564  0.370073 -0.205060
# exang    -0.089225 -0.404349  1.000000  0.294308 -0.280124  0.106250
# oldpeak  -0.047837 -0.340564  0.294308  1.000000 -0.585472  0.223375
# slope     0.074982  0.370073 -0.280124 -0.585472  1.000000 -0.083491
# ca       -0.053946 -0.205060  0.106250  0.223375 -0.083491  1.000000
# thal     -0.003377 -0.078637  0.189253  0.200315 -0.090606  0.136160
# target    0.101817  0.432687 -0.457502 -0.443504  0.363983 -0.391031
#
#               thal    target
# age       0.077368 -0.244798
# sex       0.198493 -0.283776
# cp       -0.139765  0.425574
# trestbps  0.068690 -0.173239
# chol      0.121280 -0.096773
# fbs      -0.004972 -0.068845
# restecg  -0.003377  0.101817
# thalach  -0.078637  0.432687
# exang     0.189253 -0.457502
# oldpeak   0.200315 -0.443504
# slope    -0.090606  0.363983
# ca        0.136160 -0.391031
# thal      1.000000 -0.311701
# target   -0.311701  1.000000

# %% [markdown]
# #### Converting the DataFrame to a NumPy Array

# %%
import numpy as np

np_data = df.values
np_data.shape
# Out:
# (270, 14)

# %%
split_point = int(np_data.shape[0]*0.7) # np_data.shape[0] 代表 np_data 的總列數（即樣本數），並將 70% 分配給訓練集

np.random.shuffle(np_data) # 隨機排列列順序，相當於打亂樣本

x_train = np_data[:split_point, :13] # 取出前 70% 的資料，並只取前 13 欄
y_train = np_data[:split_point, 13]
x_val = np_data[split_point:, :13] # 取出剩下 30 % 的資料（split_point 後所有），並只取前 13 欄
y_val = np_data[split_point:, 13]

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

# Convert to PyTorch tensors
x_train = np.array(x_train, dtype=float) # 將 NumPy 陣列轉換為 PyTorch Tensor；因為 x_train 通常是連續資料，所以 .float() 將其轉換為 float32 類型，讓 PyTorch 模型可以處理
x_train = torch.from_numpy(x_train).float()
y_train = np.array(y_train, dtype=int)
y_train = torch.from_numpy(y_train).long() # PyTorch 的分類模型通常要求類別 (y_train) 是整數型 (long)，因為交叉熵 (CrossEntropyLoss) 需要 long 類型的標籤

x_val = np.array(x_val, dtype=float)
x_val = torch.from_numpy(x_val).float()
y_val = np.array(y_val, dtype=int)
y_val = torch.from_numpy(y_val).long()

batch_size = 64 # 更改

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True) # DataLoader 會把 train_dataset 拆分成 batch，並在訓練時一批一批地載入數據，訓練集打亂、驗證集不打亂
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
# Out:
# Number of samples in train and validation are 189 and 81.

# %% [markdown]
# ## B. Defining Neural Networks
#
# In PyTorch, we can use **class** to define our custom neural network architectures by subclassing the `nn.Module` class. This gives our neural network all the functionality it needs to work with PyTorch's other utilities and keeps our implementation organized.
#
# - Neural networks are defined by subclassing `nn.Module`.
# - The layers of the neural network are initialized in the `__init__` method.
# - The forward pass operations on input data are defined in the `forward` method.
#
# It's worth noting that while we only define the forward pass, PyTorch will automatically derive the backward pass for us, which is used during training to update the model's weights."

# %%
import torch.nn as nn

class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential( # 順序地堆疊神經網路層
            nn.Linear(13, 256), # (input features, output features)
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 2)
        ).cuda()

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## C. Training the Neural Network

# %%
# Check your GPU status.
# !nvidia-smi
# Out:
# Fri Mar 21 08:32:26 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR # CosineAnnealingLR 為餘弦退火學習率調整 (Cosine Annealing Learning Rate Scheduler)，讓學習率逐漸降低
from tqdm.auto import tqdm # 讓訓練時顯示進度條

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 100

model = Model()
# print(model)

# 儲存最佳模型的表現，如果當前 epoch 比之前好，就覆蓋
best_val_loss = float('inf') # 負無限大
best_val_acc = -1

criterion = nn.CrossEntropyLoss() # 用於分類問題的損失函數，PyTorch 內部會自動加 Softmax 計算每個類別的機率，所以 Model 最後一層不用 Softmax
optimizer = optim.Adam(model.parameters(), lr=5e-3) # 更改 # Gradient Descent 使用 Adam 優化器，學習率 0.001
lr_scheduler = CosineAnnealingLR(optimizer, T_max=epochs, eta_min=0)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for features, labels in train_loader: # 一次 load 一個 batch
        features = features.cuda() # 使用 GPU 計算
        labels = labels.cuda()

        outputs = model(features) # outputs 的張量形狀會是 (batch size, num classes)，通常代表有 batch size 個樣本，每個樣本有 num classes 的分數

        loss = criterion(outputs, labels) # 利用 CrossEntropy 計算 loss
        total_loss += loss.item()

        optimizer.zero_grad() # 清空梯度防止累積
        loss.backward() # back-propagation 計算梯度
        optimizer.step() # 使用 Adam 更新模型參數

        train_predicted = outputs.argmax(-1) # 在 output 最後一個維度 (num classes) 上找最大值的索引，也就是預測機率最高的類別
        train_correct += (train_predicted == labels).sum().item() # 計算正確預測的數量
        total_train_samples += labels.size(0)

    # Learning rate update
    lr_scheduler.step()

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad(): # 驗證停止梯度計算
        for features, labels in val_loader:
            features = features.cuda()
            labels = labels.cuda()

            outputs = model(features)

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = outputs.argmax(-1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy
        torch.save(model.state_dict(), 'model_classification.pth')

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.4f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.4f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100, Train loss: 47.2306, Train acc: 48.6772%, Val loss: 20.6871, Val acc: 60.4938%, Best Val loss: 20.6871 Best Val acc: 60.49%
# Epoch 2/100, Train loss: 14.8557, Train acc: 55.0265%, Val loss: 26.0884, Val acc: 39.5062%, Best Val loss: 20.6871 Best Val acc: 60.49%
# Epoch 3/100, Train loss: 18.3125, Train acc: 48.1481%, Val loss: 3.4411, Val acc: 40.7407%, Best Val loss: 3.4411 Best Val acc: 60.49%
# Epoch 4/100, Train loss: 5.8498, Train acc: 51.8519%, Val loss: 7.5789, Val acc: 60.4938%, Best Val loss: 3.4411 Best Val acc: 60.49%
# Epoch 5/100, Train loss: 7.5458, Train acc: 51.8519%, Val loss: 1.2751, Val acc: 65.4321%, Best Val loss: 1.2751 Best Val acc: 65.43%
# Epoch 6/100, Train loss: 1.8935, Train acc: 51.8519%, Val loss: 2.8390, Val acc: 40.7407%, Best Val loss: 1.2751 Best Val acc: 65.43%
# Epoch 7/100, Train loss: 1.9137, Train acc: 56.6138%, Val loss: 0.6881, Val acc: 70.3704%, Best Val loss: 0.6881 Best Val acc: 70.37%
# Epoch 8/100, Train loss: 1.3055, Train acc: 54.4974%, Val loss: 0.7128, Val acc: 67.9012%, Best Val loss: 0.6881 Best Val acc: 70.37%
# Epoch 9/100, Train loss: 0.8023, Train acc: 58.7302%, Val loss: 0.8942, Val acc: 56.7901%, Best Val loss: 0.6881 Best Val acc: 70.37%
# Epoch 10/100, Train loss: 0.7895, Train acc: 64.5503%, Val loss: 0.6539, Val acc: 66.6667%, Best Val loss: 0.6539 Best Val acc: 70.37%
# Epoch 11/100, Train loss: 0.7030, Train acc: 66.1376%, Val loss: 0.6874, Val acc: 65.4321%, Best Val loss: 0.6539 Best Val acc: 70.37%
# Epoch 12/100, Train loss: 0.6988, Train acc: 62.9630%, Val loss: 0.5190, Val acc: 70.3704%, Best Val loss: 0.5190 Best Val acc: 70.37%
# Epoch 13/100, Train loss: 0.6443, Train acc: 64.0212%, Val loss: 0.5267, Val acc: 67.9012%, Best Val loss: 0.5190 Best Val acc: 70.37%
# Epoch 14/100, Train loss: 0.6111, Train acc: 64.5503%, Val loss: 0.6378, Val acc: 64.1975%, Best Val loss: 0.5190 Best Val acc: 70.37%
# Epoch 15/100, Train loss: 0.6090, Train acc: 64.0212%, Val loss: 0.5326, Val acc: 69.1358%, Best Val loss: 0.5190 Best Val acc: 70.37%
# Epoch 16/100, Train loss: 0.6155, Train acc: 64.0212%, Val loss: 0.5307, Val acc: 71.6049%, Best Val loss: 0.5190 Best Val acc: 71.60%
# Epoch 17/100, Train loss: 0.5725, Train acc: 69.8413%, Val loss: 0.5817, Val acc: 67.9012%, Best Val loss: 0.5190 Best Val acc: 71.60%
# Epoch 18/100, Train loss: 0.5924, Train acc: 68.2540%, Val loss: 0.5321, Val acc: 76.5432%, Best Val loss: 0.5190 Best Val acc: 76.54%
# Epoch 19/100, Train loss: 0.5718, Train acc: 68.7831%, Val loss: 0.5193, Val acc: 67.9012%, Best Val loss: 0.5190 Best Val acc: 76.54%
# Epoch 20/100, Train loss: 0.5752, Train acc: 67.1958%, Val loss: 0.5343, Val acc: 72.8395%, Best Val loss: 0.5190 Best Val acc: 76.54%
# Epoch 21/100, Train loss: 0.5685, Train acc: 71.9577%, Val loss: 0.5371, Val acc: 72.8395%, Best Val loss: 0.5190 Best Val acc: 76.54%
# Epoch 22/100, Train loss: 0.5666, Train acc: 72.4868%, Val loss: 0.5144, Val acc: 74.0741%, Best Val loss: 0.5144 Best Val acc: 76.54%
# Epoch 23/100, Train loss: 0.5698, Train acc: 68.2540%, Val loss: 0.5096, Val acc: 72.8395%, Best Val loss: 0.5096 Best Val acc: 76.54%
# Epoch 24/100, Train loss: 0.5589, Train acc: 71.9577%, Val loss: 0.5273, Val acc: 74.0741%, Best Val loss: 0.5096 Best Val acc: 76.54%
# Epoch 25/100, Train loss: 0.5835, Train acc: 69.3122%, Val loss: 0.5351, Val acc: 75.3086%, Best Val loss: 0.5096 Best Val acc: 76.54%
# Epoch 26/100, Train loss: 0.5536, Train acc: 70.3704%, Val loss: 0.5057, Val acc: 72.8395%, Best Val loss: 0.5057 Best Val acc: 76.54%
# Epoch 27/100, Train loss: 0.5673, Train acc: 69.8413%, Val loss: 0.5095, Val acc: 76.5432%, Best Val loss: 0.5057 Best Val acc: 76.54%
# Epoch 28/100, Train loss: 0.5590, Train acc: 70.3704%, Val loss: 0.5313, Val acc: 74.0741%, Best Val loss: 0.5057 Best Val acc: 76.54%
# Epoch 29/100, Train loss: 0.5543, Train acc: 71.4286%, Val loss: 0.4993, Val acc: 75.3086%, Best Val loss: 0.4993 Best Val acc: 76.54%
# Epoch 30/100, Train loss: 0.5593, Train acc: 71.9577%, Val loss: 0.5005, Val acc: 74.0741%, Best Val loss: 0.4993 Best Val acc: 76.54%
# Epoch 31/100, Train loss: 0.5785, Train acc: 71.9577%, Val loss: 0.5486, Val acc: 71.6049%, Best Val loss: 0.4993 Best Val acc: 76.54%
# Epoch 32/100, Train loss: 0.5479, Train acc: 70.3704%, Val loss: 0.4941, Val acc: 74.0741%, Best Val loss: 0.4941 Best Val acc: 76.54%
# Epoch 33/100, Train loss: 0.5568, Train acc: 69.3122%, Val loss: 0.4927, Val acc: 76.5432%, Best Val loss: 0.4927 Best Val acc: 76.54%
# Epoch 34/100, Train loss: 0.5355, Train acc: 74.6032%, Val loss: 0.5289, Val acc: 74.0741%, Best Val loss: 0.4927 Best Val acc: 76.54%
# Epoch 35/100, Train loss: 0.5462, Train acc: 73.5450%, Val loss: 0.5039, Val acc: 75.3086%, Best Val loss: 0.4927 Best Val acc: 76.54%
# Epoch 36/100, Train loss: 0.5465, Train acc: 72.4868%, Val loss: 0.4886, Val acc: 75.3086%, Best Val loss: 0.4886 Best Val acc: 76.54%
# Epoch 37/100, Train loss: 0.5389, Train acc: 73.0159%, Val loss: 0.5014, Val acc: 75.3086%, Best Val loss: 0.4886 Best Val acc: 76.54%
# Epoch 38/100, Train loss: 0.5621, Train acc: 68.7831%, Val loss: 0.5407, Val acc: 71.6049%, Best Val loss: 0.4886 Best Val acc: 76.54%
# Epoch 39/100, Train loss: 0.5355, Train acc: 71.9577%, Val loss: 0.4847, Val acc: 74.0741%, Best Val loss: 0.4847 Best Val acc: 76.54%
# Epoch 40/100, Train loss: 0.5436, Train acc: 71.9577%, Val loss: 0.4857, Val acc: 75.3086%, Best Val loss: 0.4847 Best Val acc: 76.54%
# Epoch 41/100, Train loss: 0.5367, Train acc: 71.4286%, Val loss: 0.5302, Val acc: 74.0741%, Best Val loss: 0.4847 Best Val acc: 76.54%
# Epoch 42/100, Train loss: 0.5408, Train acc: 73.5450%, Val loss: 0.4901, Val acc: 75.3086%, Best Val loss: 0.4847 Best Val acc: 76.54%
# Epoch 43/100, Train loss: 0.5329, Train acc: 72.4868%, Val loss: 0.4859, Val acc: 72.8395%, Best Val loss: 0.4847 Best Val acc: 76.54%
# Epoch 44/100, Train loss: 0.5378, Train acc: 70.8995%, Val loss: 0.5013, Val acc: 76.5432%, Best Val loss: 0.4847 Best Val acc: 76.54%
# Epoch 45/100, Train loss: 0.5270, Train acc: 76.1905%, Val loss: 0.5167, Val acc: 74.0741%, Best Val loss: 0.4847 Best Val acc: 76.54%
# Epoch 46/100, Train loss: 0.5171, Train acc: 74.0741%, Val loss: 0.4751, Val acc: 76.5432%, Best Val loss: 0.4751 Best Val acc: 76.54%
# Epoch 47/100, Train loss: 0.5170, Train acc: 74.0741%, Val loss: 0.4720, Val acc: 74.0741%, Best Val loss: 0.4720 Best Val acc: 76.54%
# Epoch 48/100, Train loss: 0.5151, Train acc: 74.0741%, Val loss: 0.4897, Val acc: 80.2469%, Best Val loss: 0.4720 Best Val acc: 80.25%
# Epoch 49/100, Train loss: 0.5105, Train acc: 75.6614%, Val loss: 0.4946, Val acc: 77.7778%, Best Val loss: 0.4720 Best Val acc: 80.25%
# Epoch 50/100, Train loss: 0.5132, Train acc: 76.1905%, Val loss: 0.4740, Val acc: 77.7778%, Best Val loss: 0.4720 Best Val acc: 80.25%
# Epoch 51/100, Train loss: 0.5042, Train acc: 75.6614%, Val loss: 0.4635, Val acc: 74.0741%, Best Val loss: 0.4635 Best Val acc: 80.25%
# Epoch 52/100, Train loss: 0.5071, Train acc: 75.6614%, Val loss: 0.4767, Val acc: 79.0123%, Best Val loss: 0.4635 Best Val acc: 80.25%
# Epoch 53/100, Train loss: 0.4994, Train acc: 74.6032%, Val loss: 0.4893, Val acc: 77.7778%, Best Val loss: 0.4635 Best Val acc: 80.25%
# Epoch 54/100, Train loss: 0.4984, Train acc: 76.1905%, Val loss: 0.4698, Val acc: 77.7778%, Best Val loss: 0.4635 Best Val acc: 80.25%
# Epoch 55/100, Train loss: 0.5033, Train acc: 77.2487%, Val loss: 0.4591, Val acc: 74.0741%, Best Val loss: 0.4591 Best Val acc: 80.25%
# Epoch 56/100, Train loss: 0.5022, Train acc: 75.6614%, Val loss: 0.4821, Val acc: 81.4815%, Best Val loss: 0.4591 Best Val acc: 81.48%
# Epoch 57/100, Train loss: 0.4930, Train acc: 76.1905%, Val loss: 0.4695, Val acc: 79.0123%, Best Val loss: 0.4591 Best Val acc: 81.48%
# Epoch 58/100, Train loss: 0.4863, Train acc: 75.6614%, Val loss: 0.4581, Val acc: 77.7778%, Best Val loss: 0.4581 Best Val acc: 81.48%
# Epoch 59/100, Train loss: 0.4902, Train acc: 76.7196%, Val loss: 0.4526, Val acc: 77.7778%, Best Val loss: 0.4526 Best Val acc: 81.48%
# Epoch 60/100, Train loss: 0.4879, Train acc: 76.1905%, Val loss: 0.4700, Val acc: 80.2469%, Best Val loss: 0.4526 Best Val acc: 81.48%
# Epoch 61/100, Train loss: 0.4849, Train acc: 74.6032%, Val loss: 0.4591, Val acc: 80.2469%, Best Val loss: 0.4526 Best Val acc: 81.48%
# Epoch 62/100, Train loss: 0.4898, Train acc: 77.7778%, Val loss: 0.4432, Val acc: 77.7778%, Best Val loss: 0.4432 Best Val acc: 81.48%
# Epoch 63/100, Train loss: 0.4827, Train acc: 77.2487%, Val loss: 0.4629, Val acc: 80.2469%, Best Val loss: 0.4432 Best Val acc: 81.48%
# Epoch 64/100, Train loss: 0.4775, Train acc: 76.1905%, Val loss: 0.4615, Val acc: 80.2469%, Best Val loss: 0.4432 Best Val acc: 81.48%
# Epoch 65/100, Train loss: 0.4776, Train acc: 77.2487%, Val loss: 0.4468, Val acc: 77.7778%, Best Val loss: 0.4432 Best Val acc: 81.48%
# Epoch 66/100, Train loss: 0.4737, Train acc: 78.8360%, Val loss: 0.4480, Val acc: 79.0123%, Best Val loss: 0.4432 Best Val acc: 81.48%
# Epoch 67/100, Train loss: 0.4692, Train acc: 78.3069%, Val loss: 0.4602, Val acc: 80.2469%, Best Val loss: 0.4432 Best Val acc: 81.48%
# Epoch 68/100, Train loss: 0.4704, Train acc: 78.3069%, Val loss: 0.4565, Val acc: 80.2469%, Best Val loss: 0.4432 Best Val acc: 81.48%
# Epoch 69/100, Train loss: 0.4694, Train acc: 77.2487%, Val loss: 0.4520, Val acc: 80.2469%, Best Val loss: 0.4432 Best Val acc: 81.48%
# Epoch 70/100, Train loss: 0.4773, Train acc: 78.3069%, Val loss: 0.4386, Val acc: 77.7778%, Best Val loss: 0.4386 Best Val acc: 81.48%
# Epoch 71/100, Train loss: 0.4654, Train acc: 77.7778%, Val loss: 0.4473, Val acc: 81.4815%, Best Val loss: 0.4386 Best Val acc: 81.48%
# Epoch 72/100, Train loss: 0.4772, Train acc: 77.7778%, Val loss: 0.4747, Val acc: 79.0123%, Best Val loss: 0.4386 Best Val acc: 81.48%
# Epoch 73/100, Train loss: 0.4717, Train acc: 79.3651%, Val loss: 0.4420, Val acc: 80.2469%, Best Val loss: 0.4386 Best Val acc: 81.48%
# Epoch 74/100, Train loss: 0.4595, Train acc: 79.3651%, Val loss: 0.4369, Val acc: 79.0123%, Best Val loss: 0.4369 Best Val acc: 81.48%
# Epoch 75/100, Train loss: 0.4598, Train acc: 78.3069%, Val loss: 0.4374, Val acc: 79.0123%, Best Val loss: 0.4369 Best Val acc: 81.48%
# Epoch 76/100, Train loss: 0.4591, Train acc: 78.8360%, Val loss: 0.4475, Val acc: 80.2469%, Best Val loss: 0.4369 Best Val acc: 81.48%
# Epoch 77/100, Train loss: 0.4563, Train acc: 78.3069%, Val loss: 0.4438, Val acc: 80.2469%, Best Val loss: 0.4369 Best Val acc: 81.48%
# Epoch 78/100, Train loss: 0.4575, Train acc: 78.3069%, Val loss: 0.4427, Val acc: 81.4815%, Best Val loss: 0.4369 Best Val acc: 81.48%
# Epoch 79/100, Train loss: 0.4566, Train acc: 79.8942%, Val loss: 0.4331, Val acc: 80.2469%, Best Val loss: 0.4331 Best Val acc: 81.48%
# Epoch 80/100, Train loss: 0.4546, Train acc: 79.3651%, Val loss: 0.4342, Val acc: 79.0123%, Best Val loss: 0.4331 Best Val acc: 81.48%
# Epoch 81/100, Train loss: 0.4541, Train acc: 79.8942%, Val loss: 0.4373, Val acc: 81.4815%, Best Val loss: 0.4331 Best Val acc: 81.48%
# Epoch 82/100, Train loss: 0.4549, Train acc: 79.8942%, Val loss: 0.4449, Val acc: 80.2469%, Best Val loss: 0.4331 Best Val acc: 81.48%
# Epoch 83/100, Train loss: 0.4535, Train acc: 79.8942%, Val loss: 0.4403, Val acc: 81.4815%, Best Val loss: 0.4331 Best Val acc: 81.48%
# Epoch 84/100, Train loss: 0.4514, Train acc: 79.8942%, Val loss: 0.4365, Val acc: 81.4815%, Best Val loss: 0.4331 Best Val acc: 81.48%
# Epoch 85/100, Train loss: 0.4499, Train acc: 79.3651%, Val loss: 0.4323, Val acc: 79.0123%, Best Val loss: 0.4323 Best Val acc: 81.48%
# Epoch 86/100, Train loss: 0.4532, Train acc: 79.8942%, Val loss: 0.4309, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 87/100, Train loss: 0.4499, Train acc: 79.3651%, Val loss: 0.4338, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 88/100, Train loss: 0.4489, Train acc: 80.4233%, Val loss: 0.4380, Val acc: 81.4815%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 89/100, Train loss: 0.4490, Train acc: 80.4233%, Val loss: 0.4394, Val acc: 81.4815%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 90/100, Train loss: 0.4487, Train acc: 79.8942%, Val loss: 0.4379, Val acc: 81.4815%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 91/100, Train loss: 0.4481, Train acc: 80.4233%, Val loss: 0.4363, Val acc: 81.4815%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 92/100, Train loss: 0.4489, Train acc: 79.3651%, Val loss: 0.4342, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 93/100, Train loss: 0.4475, Train acc: 79.3651%, Val loss: 0.4338, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 94/100, Train loss: 0.4469, Train acc: 78.8360%, Val loss: 0.4339, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 95/100, Train loss: 0.4489, Train acc: 79.8942%, Val loss: 0.4335, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 96/100, Train loss: 0.4476, Train acc: 79.3651%, Val loss: 0.4336, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 97/100, Train loss: 0.4479, Train acc: 79.3651%, Val loss: 0.4337, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 98/100, Train loss: 0.4467, Train acc: 79.8942%, Val loss: 0.4338, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 99/100, Train loss: 0.4465, Train acc: 79.8942%, Val loss: 0.4338, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%
# Epoch 100/100, Train loss: 0.4471, Train acc: 79.8942%, Val loss: 0.4338, Val acc: 80.2469%, Best Val loss: 0.4309 Best Val acc: 81.48%

# %% [markdown]
# #### Visualizing the model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# read test file
test_data = pd.read_csv('heart_dataset_test.csv')
test_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   50    0   2       120   219    0        1      158      0      1.6      1
# 1   58    0   2       120   340    0        1      172      0      0.0      2
# 2   66    0   3       150   226    0        1      114      0      2.6      0
# 3   43    1   0       150   247    0        1      171      0      1.5      2
# 4   69    0   3       140   239    0        1      151      0      1.8      2
#
#    ca  thal  target
# 0   0     2       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   2     2       1

# %%
test_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
test_data = test_data.values
test_data.shape
# Out:
# (31, 14)

# %%
# Convert to PyTorch tensors
x_test = torch.from_numpy(test_data[:, :13]).float()
y_test = torch.from_numpy(test_data[:, 13]).long()

# Create datasets
test_dataset = TensorDataset(x_test, y_test)

# Create dataloaders
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for features, labels in test_loader:

        features = features.cuda()
        labels = labels.cuda()

        outputs = model(features)

        predicted = outputs.argmax(-1)
        test_correct += (predicted == labels).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# Test accuracy is 64.51612903225806%
